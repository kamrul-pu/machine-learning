# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)
training_set = train_datagen.flow_from_directory(
    "dataset/training_set",
    target_size=(64, 64),
    batch_size=32,
    class_mode="binary")
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
    "dataset/test_set",
    target_size=(64, 64),
    batch_size=32,
    class_mode="binary")
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
# Add an Input layer specifying the input shape
cnn.add(tf.keras.layers.Input(shape=[64, 64, 3]))
# Add the Conv2D layer without specifying input_shape
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu"))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu"))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation="relu"))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Epoch 1/25
# C:\Users\Admin\Desktop\machine-learning\venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 133s 511ms/step - accuracy: 0.5558 - loss: 0.6870 - val_accuracy: 0.6725 - val_loss: 0.6016
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 177ms/step - accuracy: 0.6780 - loss: 0.5997 - val_accuracy: 0.7165 - val_loss: 0.5711
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 178ms/step - accuracy: 0.7049 - loss: 0.5637 - val_accuracy: 0.7135 - val_loss: 0.5767
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.7362 - loss: 0.5272 - val_accuracy: 0.7485 - val_loss: 0.5241
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 174ms/step - accuracy: 0.7401 - loss: 0.5128 - val_accuracy: 0.7610 - val_loss: 0.5181
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.7694 - loss: 0.4798 - val_accuracy: 0.7515 - val_loss: 0.5132
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 175ms/step - accuracy: 0.7752 - loss: 0.4676 - val_accuracy: 0.7455 - val_loss: 0.5152
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.7979 - loss: 0.4433 - val_accuracy: 0.7570 - val_loss: 0.5150
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.7995 - loss: 0.4338 - val_accuracy: 0.7840 - val_loss: 0.4605
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.8086 - loss: 0.4218 - val_accuracy: 0.7775 - val_loss: 0.4701
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 177ms/step - accuracy: 0.8154 - loss: 0.3975 - val_accuracy: 0.7830 - val_loss: 0.4632
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.8278 - loss: 0.3918 - val_accuracy: 0.7940 - val_loss: 0.4553
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 56s 220ms/step - accuracy: 0.8281 - loss: 0.3781 - val_accuracy: 0.8010 - val_loss: 0.4719
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 179ms/step - accuracy: 0.8341 - loss: 0.3709 - val_accuracy: 0.8020 - val_loss: 0.4569
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.8367 - loss: 0.3645 - val_accuracy: 0.7945 - val_loss: 0.4561
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 177ms/step - accuracy: 0.8349 - loss: 0.3687 - val_accuracy: 0.8110 - val_loss: 0.4366
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.8493 - loss: 0.3417 - val_accuracy: 0.8205 - val_loss: 0.4346
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 178ms/step - accuracy: 0.8456 - loss: 0.3499 - val_accuracy: 0.8010 - val_loss: 0.4685
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 190ms/step - accuracy: 0.8599 - loss: 0.3219 - val_accuracy: 0.8040 - val_loss: 0.4815
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 189ms/step - accuracy: 0.8612 - loss: 0.3166 - val_accuracy: 0.7890 - val_loss: 0.5137
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 180ms/step - accuracy: 0.8712 - loss: 0.3024 - val_accuracy: 0.8240 - val_loss: 0.4713
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 181ms/step - accuracy: 0.8651 - loss: 0.3093 - val_accuracy: 0.7950 - val_loss: 0.4911
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 179ms/step - accuracy: 0.8747 - loss: 0.3015 - val_accuracy: 0.8055 - val_loss: 0.4694
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 178ms/step - accuracy: 0.8780 - loss: 0.2804 - val_accuracy: 0.8135 - val_loss: 0.4529
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 180ms/step - accuracy: 0.8720 - loss: 0.2915 - val_accuracy: 0.8095 - val_loss: 0.4622

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img("dataset/single_prediction/cat_or_dog_4.jpg", target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
training_set.class_indices
prediction = ""
if result[0][0] == 1:
    prediction = "dog"
else:
    prediction = "cat"
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
print(prediction)
# Out:
# dog

# %%
import os
print(os.getcwd())
# Save the model in TensorFlow SavedModel format
cnn.save('\model')

# Save the model in HDF5 format
cnn.save('\model.h5')
# Out:
# C:\Users\Admin\Desktop\machine-learning\ml-udemy\9_deep_learning
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 4
#       2 print(os.getcwd())
#       3 # Save the model in TensorFlow SavedModel format
# ----> 4 cnn.save('\model')
#       6 # Save the model in HDF5 format
#       7 cnn.save('\model.h5')
#
# File ~\Desktop\machine-learning\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\Desktop\machine-learning\venv\Lib\site-packages\keras\src\saving\saving_api.py:114, in save_model(model, filepath, overwrite, zipped, **kwargs)
#     110 if str(filepath).endswith((".h5", ".hdf5")):
#     111     return legacy_h5_format.save_model_to_hdf5(
#     112         model, filepath, overwrite, include_optimizer
#     113     )
# --> 114 raise ValueError(
#     115     "Invalid filepath extension for saving. "
#     116     "Please add either a `.keras` extension for the native Keras "
#     117     f"format (recommended) or a `.h5` extension. "
#     118     "Use `model.export(filepath)` if you want to export a SavedModel "
#     119     "for use with TFLite/TFServing/etc. "
#     120     f"Received: filepath={filepath}."
#     121 )
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=\model.
